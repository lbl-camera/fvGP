# %% [markdown]
# # FVGP Single Task Notebook
#
# In this notebook we will go through a few features of fvGP.
# We will be primarily concerned with regression over a single dimension output and single task.
# See the multiple_task_test_notebook.ipynb for single dimension and multiple task example.
# The extension to multiple dimensions is straight forward.
#
# NOTE: in this example, all outputs are hidden except for the plots.
#
# ## TEST TEST TEST
#
# ## Simple Example
#
# Simple setup and training for fvgp single task.
#
# ### Import fvgp and relevant libraries

# %%
import fvgp
from fvgp import gp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Defining some input data and testing points

# %%
def test_data_function(x):
    return np.sin(0.1 * x)+np.cos(0.05 * x)

# %%
x_input = np.linspace(-2*np.pi, 10*np.pi,20)

# %%
y_output = test_data_function(x_input)

# %%
x_input_test = np.linspace(-2*np.pi, 10*np.pi, 100)

# %% [markdown]
# ### Setting up the fvgp single task object
#
# NOTE: The input data need to be given in the form (N x input_space_dim).
# The output can either be a N array or N x 1 array where N is the number of data points.
# See help(gp.GP) for more information.

# %%
obj = gp.GP(input_space_dim = 1,
            points = x_input.reshape(-1,1),
            values = y_output.reshape(-1,1),
            init_hyperparameters = np.array([10,10]))
# Out:
# CAUTION: you have not provided data variances in fvGP,
# they will be set to 1 percent of the data values!
# fvGP successfully initiated

# %% [markdown]
# ### Training our gaussian process regression on given data

# %%
hyper_param_bounds = np.array([[0.0001, 1000000],[ 0.000001, 100]])
##this will block the main thread, even if you use "hgdl", another option is "global" or "local"
print("Blocking main thread...")
obj.train(hyper_param_bounds, method = "hgdl")
print("free again")
print("this also killed the client")
# Out:
# Blocking main thread...
# fvGP training started with  20  data points
# fvGP hyperparameter tuning in progress. Old hyperparameters:  [10 10]  with old log likelihood:  31.006951502741696
# method:  hgdl
# fvGP submitted HGDL optimization
# bounds are [[1.e-04 1.e+06]
#  [1.e-06 1.e+02]]
# HGDL successfully initiated
# deflation radius set to  0.099999999
# Hessian was provided by the user: <bound method GP.log_likelihood_hessian of <fvgp.gp.GP object at 0x7ff7b5f114f0>>
# ========================
# No dask client provided to HGDL. Using the local client
# Host  tcp://127.0.0.1:34819  has  3  workers.
# <Client: 'tcp://127.0.0.1:39383' processes=4 threads=8, memory=15.54 GiB>
# HGDL starts with:  [[1.00000000e+01 1.00000000e+01]
#  [2.14254770e+05 2.41820235e+01]
#  [4.99467599e+04 9.83674899e+00]]
# HGDL computing epoch 1 of  120
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:41887  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:42045  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:43735  ; method:  L-BFGS-B  tol:  1e-06
# CAUTION: points converged too close to each other in HGDL; point removed
# CAUTION: points converged too close to each other in HGDL; point removed
# HGDL computing epoch  2  of  120
# Global optimizer:  genetic
# =========================
# Children in HGDL genetic alg.:
# [[5.06690906e+04 5.70156657e+01]
#  [5.15011900e+05 8.69898963e+00]
#  [1.01448346e+04 4.77717706e+01]]
# =========================
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:41887  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:42045  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:43735  ; method:  L-BFGS-B  tol:  1e-06
# HGDL computing epoch  3  of  120
# Global optimizer:  genetic
# =========================
# Children in HGDL genetic alg.:
# [[7.47143859e+03 5.43617584e+01]
#  [1.12959447e+02 7.72589607e+01]
#  [7.80953442e+04 8.65925115e+01]]
# =========================
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:41887  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:42045  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:43735  ; method:  L-BFGS-B  tol:  1e-06
# CAUTION: points converged too close to each other in HGDL; point removed
# HGDL computing epoch  4  of  120
# Global optimizer:  genetic
# =========================
# Children in HGDL genetic alg.:
# [[2.07090215e+04 2.90736291e+01]
#  [5.02769101e+05 7.12904064e+01]
#  [2.39685154e+04 7.77243754e+01]]
# =========================
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:41887  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:42045  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:43735  ; method:  L-BFGS-B  tol:  1e-06
# CAUTION: points converged too close to each other in HGDL; point removed
# CAUTION: points converged too close to each other in HGDL; point removed
# HGDL computing epoch  5  of  120
# Global optimizer:  genetic
# =========================
# Children in HGDL genetic alg.:
# [[1.78237014e+04 5.17100207e+01]
#  [9.90783051e+03 5.35999246e+01]
#  [7.45690088e+04 3.19030542e+01]]
# =========================
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:41887  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:42045  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:43735  ; method:  L-BFGS-B  tol:  1e-06
# CAUTION: points converged too close to each other in HGDL; point removed
# HGDL computing epoch  6  of  120
# Global optimizer:  genetic
# =========================
# Children in HGDL genetic alg.:
# [[24290.74345367    49.42389731]
#  [11576.92942596    49.49095687]
#  [25079.06401669    56.39322001]]
# =========================
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:41887  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:42045  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:43735  ; method:  L-BFGS-B  tol:  1e-06
# HGDL computing epoch
+01]]
# =========================
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:41887  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:42045  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:43735  ; method:  L-BFGS-B  tol:  1e-06
# HGDL computing epoch  119  of  120
# Global optimizer:  genetic
# =========================
# Children in HGDL genetic alg.:
# [[2.26195264e+03 4.42613515e+01]
#  [7.39944770e+04 4.99396552e+01]
#  [1.62975099e+04 5.67886609e+01]]
# =========================
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:41887  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:42045  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:43735  ; method:  L-BFGS-B  tol:  1e-06
# CAUTION: points converged too close to each other in HGDL; point removed
# HGDL computing epoch  120  of  120
# Global optimizer:  genetic
# =========================
# Children in HGDL genetic alg.:
# [[7.18192448e+05 2.15805391e+01]
#  [1.29061455e+05 5.21410811e+01]
#  [8.06641547e+04 5.10456218e+01]]
# =========================
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:41887  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:42045  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:43735  ; method:  L-BFGS-B  tol:  1e-06
# HGDL kill client initialized ...
# HGDL called get_latest() successfully
# HGDL finished all epochs!
# /home/ihumphrey/miniconda3/envs/fvGP-3.8/lib/python3.8/site-packages/scipy/optimize/_minimize.py:527: RuntimeWarning: Method L-BFGS-B does not use Hessian information (hess).
#   warn('Method %s does not use Hessian information (hess).' % method,
# /home/ihumphrey/Dev/fvGP/fvgp/gp.py:1468: RuntimeWarning: divide by zero encountered in true_divide
#   distance_matrix += abs(np.subtract.outer(x1[:,i],x2[:,i])/hps[1+i])**2
# /home/ihumphrey/Dev/fvGP/fvgp/gp.py:1468: RuntimeWarning: invalid value encountered in true_divide
#   distance_matrix += abs(np.subtract.outer(x1[:,i],x2[:,i])/hps[1+i])**2
# /home/ihumphrey/miniconda3/envs/fvGP-3.8/lib/python3.8/site-packages/scipy/optimize/_minimize.py:527: RuntimeWarning: Method L-BFGS-B does not use Hessian information (hess).
#   warn('Method %s does not use Hessian information (hess).' % method,
# /home/ihumphrey/Dev/fvGP/fvgp/gp.py:1468: RuntimeWarning: divide by zero encountered in true_divide
#   distance_matrix += abs(np.subtract.outer(x1[:,i],x2[:,i])/hps[1+i])**2
# /home/ihumphrey/Dev/fvGP/fvgp/gp.py:1468: RuntimeWarning: invalid value encountered in true_divide
#   distance_matrix += abs(np.subtract.outer(x1[:,i],x2[:,i])/hps[1+i])**2
# /home/ihumphrey/miniconda3/envs/fvGP-3.8/lib/python3.8/site-packages/scipy/optimize/_minimize.py:527: RuntimeWarning: Method L-BFGS-B does not use Hessian information (hess).
#   warn('Method %s does not use Hessian information (hess).' % method,
# /home/ihumphrey/Dev/fvGP/fvgp/gp.py:1468: RuntimeWarning: divide by zero encountered in true_divide
#   distance_matrix += abs(np.subtract.outer(x1[:,i],x2[:,i])/hps[1+i])**2
# /home/ihumphrey/Dev/fvGP/fvgp/gp.py:1468: RuntimeWarning: invalid value encountered in true_divide
#   distance_matrix += abs(np.subtract.outer(x1[:,i],x2[:,i])/hps[1+i])**2
# HGDL kill client successful
# free again
# this also killed the client

# %% [markdown]
# ### Looking the posterior mean at the test points

# %%
post_mean= obj.posterior_mean(x_input_test.reshape(-1,1))

# %%
plt.plot(x_input_test, post_mean['f(x)'], label='gp interpolation')
plt.scatter(x_input, y_output, label='data')
plt.plot(x_input_test,test_data_function(x_input_test), label = '')
plt.legend()

# %% [markdown]
# ## Training Asynchronously

# %%
obj = gp.GP(input_space_dim = 1,
            points = x_input.reshape(-1,1),
            values = y_output.reshape(-1,1),
            init_hyperparameters = np.array([10,10]),
            variances = np.zeros(y_output.reshape(-1,1).shape))
# Out:
# fvGP successfully initiated

# %%
hyper_param_bounds = np.array([[0.0001, 100], [ 0.0001, 100]])

# %%
async_obj = obj.train_async(hyper_param_bounds)
# Out:
# Async fvGP training started with  20  data points
# fvGP submitted HGDL optimization for asynchronous training
# bounds: [[1.e-04 1.e+02]
#  [1.e-04 1.e+02]]
# deflation radius:  None
# local optimizer:  L-BFGS-B
# global optimizer:  genetic
# HGDL successfully initiated
# deflation radius set to  0.0999999
# Hessian was provided by the user: <bound method GP.log_likelihood_hessian of <fvgp.gp.GP object at 0x7ff83d622c70>>
# ========================
# dask client provided to HGDL
# Host  tcp://127.0.0.1:33015  has  3  workers.
# <Client: 'tcp://127.0.0.1:42477' processes=4 threads=8, memory=15.54 GiB>
# HGDL starts with:  [[10.         10.        ]
#  [11.89844439 16.74196111]
#  [64.68087527 52.0187732 ]]

# %% [markdown]
# ### Updating asynchronously
#
# Updates hyperparameters to current optimization values

# %%
obj.update_hyperparameters(async_obj)
# Out:
# HGDL computing epoch 1 of  10000
# Updating the hyperparameters in fvGP...
# HGDL called get_latest() successfully
#     Async Hyper-parameter update not successful in fvGP. I am keeping the old ones.
#     That probably means you are not optimizing them asynchronously
#     Here is the actual reason:  index 0 is out of bounds for axis 0 with size 0
#     hyperparameters:  [10 10]
# array([10, 10])

# %% [markdown]
# ### Killing training

# %%
obj.kill_training(async_obj)
# Out:
# fvGP is killing asynchronous training....
# HGDL kill client initialized ...
# HGDL called get_latest() successfully
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:34807  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:44757  ; method:  L-BFGS-B  tol:  1e-06
# HGDL says: local optimizer submitted to worker  tcp://127.0.0.1:46699  ; method:  L-BFGS-B  tol:  1e-06
# CAUTION: points converged too close to each other in HGDL; point removed
# CAUTION: points converged too close to each other in HGDL; point removed
# HGDL Epoch  1  was cancelled
# HGDL finished all epochs!
# /home/ihumphrey/miniconda3/envs/fvGP-3.8/lib/python3.8/site-packages/scipy/optimize/_minimize.py:527: RuntimeWarning: Method L-BFGS-B does not use Hessian information (hess).
#   warn('Method %s does not use Hessian information (hess).' % method,
# /home/ihumphrey/miniconda3/envs/fvGP-3.8/lib/python3.8/site-packages/scipy/optimize/_minimize.py:527: RuntimeWarning: Method L-BFGS-B does not use Hessian information (hess).
#   warn('Method %s does not use Hessian information (hess).' % method,
# /home/ihumphrey/miniconda3/envs/fvGP-3.8/lib/python3.8/site-packages/scipy/optimize/_minimize.py:527: RuntimeWarning: Method L-BFGS-B does not use Hessian information (hess).
#   warn('Method %s does not use Hessian information (hess).' % method,
# HGDL kill client successful
# fvGP successfully killed the training.

# %% [markdown]
# ### Looking the posterior mean at the test points

# %%
post_mean= obj.posterior_mean(x_input_test.reshape(-1,1))

# %%
plt.plot(x_input_test, post_mean['f(x)'], label='interpolation')
plt.plot(x_input_test, test_data_function(x_input_test), label='ground truth')
plt.legend()

# %% [markdown]
# ## Custom Kernels

# %%
def kernel_l1(x1,x2, hp, obj):
    ################################################################
    ###standard anisotropic kernel in an input space with l1########
    ################################################################
    d1 = abs(np.subtract.outer(x1[:,0],x2[:,0])) 
    return hp[0] * np.exp(-d1/hp[1])

# %%
obj = gp.GP(input_space_dim = 1,
            points = x_input.reshape(-1,1),
            values = y_output.reshape(-1,1),
            init_hyperparameters = np.array([10,10]),
            variances = np.zeros(y_output.reshape(-1,1).shape),
            gp_kernel_function = kernel_l1)
# Out:
# fvGP successfully initiated

# %% [markdown]
# ### Training our gaussian process regression on given data

# %%
hyper_param_bounds = np.array([[0.0001, 1000],[ 0.0001, 1000]])
obj.train(hyper_param_bounds)
# Out:
# fvGP training started with  20  data points
# fvGP hyperparameter tuning in progress. Old hyperparameters:  [10 10]  with old log likelihood:  30.952325741923985
# method:  global
# fvGP is performing a global differential evolution algorithm to find the optimal hyperparameters.
# maximum number of iterations:  120
# termination tolerance:  0.0001
# bounds:  [[1.e-04 1.e+03]
#  [1.e-04 1.e+03]]
# differential_evolution step 1: f(x)= -3.40768
# differential_evolution step 2: f(x)= -3.40768
# differential_evolution step 3: f(x)= -3.40768
# differential_evolution step 4: f(x)= -3.40768
# differential_evolution step 5: f(x)= -3.73888
# differential_evolution step 6: f(x)= -3.73888
# differential_evolution step 7: f(x)= -3.73888
# differential_evolution step 8: f(x)= -3.73888
# differential_evolution step 9: f(x)= -3.81137
# differential_evolution step 10: f(x)= -3.91757
# differential_evolution step 11: f(x)= -3.91757
# differential_evolution step 12: f(x)= -3.91757
# differential_evolution step 13: f(x)= -3.91757
# differential_evolution step 14: f(x)= -3.91757
# differential_evolution step 15: f(x)= -3.91757
# differential_evolution step 16: f(x)= -3.91757
# differential_evolution step 17: f(x)= -3.91757
# differential_evolution step 18: f(x)= -3.91757
# differential_evolution step 19: f(x)= -3.91839
# differential_evolution step 20: f(x)= -3.92236
# differential_evolution step 21: f(x)= -3.92236
# differential_evolution step 22: f(x)= -3.92236
# differential_evolution step 23: f(x)= -3.92338
# differential_evolution step 24: f(x)= -3.92338
# differential_evolution step 25: f(x)= -3.92338
# differential_evolution step 26: f(x)= -3.92342
# differential_evolution step 27: f(x)= -3.92342
# differential_evolution step 28: f(x)= -3.92342
# differential_evolution step 29: f(x)= -3.92342
# differential_evolution step 30: f(x)= -3.92343
# differential_evolution step 31: f(x)= -3.92344
# differential_evolution step 32: f(x)= -3.92345
# differential_evolution step 33: f(x)= -3.92345
# fvGP found hyperparameters  [ 0.70468532 80.28149319]  with likelihood  -3.9234459521492084  via global optimization

# %% [markdown]
# ### Looking the posterior mean at the test points

# %%
post_mean= obj.posterior_mean(x_input_test.reshape(-1,1))

# %%
plt.plot(x_input_test, post_mean['f(x)'], label='interpolation')
plt.plot(x_input_test, test_data_function(x_input_test), label='ground truth')
plt.legend()

# %% [markdown]
# ## Prior Mean Functions
#
# NOTE: The prior mean function must return a 1d vector, e.g., (100,)

# %%
def example_mean(gp_obj,x,hyperparameters):
    return np.ones(len(x))

# %%
obj = gp.GP(input_space_dim = 1,
            points = x_input.reshape(-1,1),
            values = y_output.reshape(-1,1),
            init_hyperparameters = np.array([10,10]),
            variances = np.zeros(y_output.reshape(-1,1).shape),
            gp_mean_function = example_mean)
# Out:
# fvGP successfully initiated

# %% [markdown]
# ### Training our gaussian process regression on given data

# %%
hyper_param_bounds = np.array([[0.0001, 1000],[ 0.0001, 1000]])
obj.train(hyper_param_bounds)
# Out:
# fvGP training started with  20  data points
# fvGP hyperparameter tuning in progress. Old hyperparameters:  [10 10]  with old log likelihood:  30.94409135792279
# method:  global
# fvGP is performing a global differential evolution algorithm to find the optimal hyperparameters.
# maximum number of iterations:  120
# termination tolerance:  0.0001
# bounds:  [[1.e-04 1.e+03]
#  [1.e-04 1.e+03]]
# differential_evolution step 1: f(x)= -1.7755
# differential_evolution step 2: f(x)= -1.7755
# differential_evolution step 3: f(x)= -3.00106
# differential_evolution step 4: f(x)= -3.00106
# differential_evolution step 5: f(x)= -3.30688
# differential_evolution step 6: f(x)= -3.30688
# differential_evolution step 7: f(x)= -3.30688
# differential_evolution step 8: f(x)= -3.30688
# differential_evolution step 9: f(x)= -3.51287
# differential_evolution step 10: f(x)= -3.89774
# differential_evolution step 11: f(x)= -3.89774
# differential_evolution step 12: f(x)= -3.89774
# differential_evolution step 13: f(x)= -3.89774
# differential_evolution step 14: f(x)= -3.89774
# differential_evolution step 15: f(x)= -3.89774
# differential_evolution step 16: f(x)= -4.031
# differential_evolution step 17: f(x)= -4.07445
# differential_evolution step 18: f(x)= -4.07445
# differential_evolution step 19: f(x)= -4.07445
# differential_evolution step 20: f(x)= -4.07445
# differential_evolution step 21: f(x)= -4.07445
# differential_evolution step 22: f(x)= -4.07445
# differential_evolution step 23: f(x)= -4.07534
# differential_evolution step 24: f(x)= -4.09106
# differential_evolution step 25: f(x)= -4.09106
# differential_evolution step 26: f(x)= -4.09106
# differential_evolution step 27: f(x)= -4.09138
# differential_evolution step 28: f(x)= -4.09163
# differential_evolution step 29: f(x)= -4.09196
# differential_evolution step 30: f(x)= -4.09208
# differential_evolution step 31: f(x)= -4.09208
# differential_evolution step 32: f(x)= -4.09209
# differential_evolution step 33: f(x)= -4.09209
# differential_evolution step 34: f(x)= -4.09209
# fvGP found hyperparameters  [ 0.54254004 61.59743048]  with likelihood  -4.0920945871312  via global optimization

# %% [markdown]
# ### Looking the posterior mean at the test points

# %%
post_mean= obj.posterior_mean(x_input_test.reshape(-1,1))

# %%
plt.plot(x_input_test, post_mean['f(x)'], label='interpolation')
plt.plot(x_input_test, test_data_function(x_input_test), label='ground truth')
plt.scatter(x_input_test,post_mean['f(x)'])
plt.legend()
