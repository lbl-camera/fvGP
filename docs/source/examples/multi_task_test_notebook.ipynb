# %% [markdown]
# # FVGP MULTI Task Notebook
# In this notebook we will go through many features of FVGP. We will be primarily concerned with regression over a single dimension output and multiple tasks.

# %% [markdown]
# ## This first cell has nothing to do with gpCAM, it's just a function to plot some results later

# %%
import plotly.graph_objects as go
import numpy as np
def plot(x,y,z,data = None):
    fig = go.Figure()
    fig.add_trace(go.Surface(x = x, y = y,z=z))
    if data is not None: 
        fig.add_trace(go.Scatter3d(x=data[:,0], y=data[:,1], z=data[:,2],
                                   mode='markers'))

    fig.update_layout(title='Posterior Mean', autosize=True,
                  width=800, height=800,
                  margin=dict(l=65, r=50, b=65, t=90))


    fig.show()

# %% [markdown]
# ## Import fvgp and relevant libraries

# %%
import fvgp
from fvgp import gp, fvgp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Defining some input data and testing points

# %%
def function(x):
    data_1 = 100*np.sin(x)+np.cos(x)
    data_2 = 5*np.ones(x.shape)
    data_3 = 1*np.cos(x/10 + 5)
    data_4 = 5*np.sin(x/200)
    data_5 = 10*np.cos(x)
    
    return np.column_stack((data_1, data_2, data_3, data_4, data_5))

# %%
x_data = np.linspace(-2*np.pi, 10*np.pi,100).reshape(-1,1)

# %%
y_data = function(x_data)

# %%
x_pred = np.linspace(3*np.pi, 4*np.pi, 100)

# %% [markdown]
# ## Setting up the fvgp multi task object

# %%
obj = fvgp.fvGP(1,1,5,x_data,y_data,
               init_hyperparameters = np.array([10,10,10]))
# Out:
# CAUTION: fvGP reports that you have not provided data variances, they will set to be 1 percent of the data values!

# %% [markdown]
# ## Training our gaussian process regression on given data

# %%
hyper_param_bounds = np.array([[0.0001, 1000],[ 0.0001, 1000],[ 0.0001, 1000]])
obj.train(hyper_param_bounds)
# Out:
# fvGP hyperparameter tuning in progress. Old hyperparameters:  [10 10 10]  with old log likelihood:  267376.70499953633
# method:  global
# fvGP is performing a global differential evolution algorithm to find the optimal hyperparameters.
# maximum number of iterations:  120
# termination tolerance:  0.0001
# bounds:  [[1.e-04 1.e+03]
#  [1.e-04 1.e+03]
#  [1.e-04 1.e+03]]
# differential_evolution step 1: f(x)= 326409
# differential_evolution step 2: f(x)= 284946
# differential_evolution step 3: f(x)= 256656
# differential_evolution step 4: f(x)= 48245.6
# differential_evolution step 5: f(x)= 48245.6
# differential_evolution step 6: f(x)= 44699.7
# differential_evolution step 7: f(x)= 4522.55
# differential_evolution step 8: f(x)= 4522.55
# differential_evolution step 9: f(x)= 4522.55
# differential_evolution step 10: f(x)= 4522.55
# differential_evolution step 11: f(x)= 1685.52
# differential_evolution step 12: f(x)= 1685.52
# differential_evolution step 13: f(x)= 1606.56
# differential_evolution step 14: f(x)= 1606.56
# differential_evolution step 15: f(x)= 1444.77
# differential_evolution step 16: f(x)= 1434.29
# differential_evolution step 17: f(x)= 1434.29
# differential_evolution step 18: f(x)= 1423.29
# differential_evolution step 19: f(x)= 1423.29
# differential_evolution step 20: f(x)= 1423.29
# differential_evolution step 21: f(x)= 1421.73
# differential_evolution step 22: f(x)= 1421.73
# differential_evolution step 23: f(x)= 1420.14
# differential_evolution step 24: f(x)= 1419.55
# differential_evolution step 25: f(x)= 1419.55
# differential_evolution step 26: f(x)= 1419.55
# differential_evolution step 27: f(x)= 1419.54
# differential_evolution step 28: f(x)= 1418.99
# differential_evolution step 29: f(x)= 1418.99
# differential_evolution step 30: f(x)= 1418.99
# differential_evolution step 31: f(x)= 1418.99
# differential_evolution step 32: f(x)= 1418.42
# differential_evolution step 33: f(x)= 1418.42
# differential_evolution step 34: f(x)= 1418.42
# differential_evolution step 35: f(x)= 1418.39
# differential_evolution step 36: f(x)= 1418.39
# differential_evolution step 37: f(x)= 1418.39
# differential_evolution step 38: f(x)= 1418.39
# differential_evolution step 39: f(x)= 1418.37
# differential_evolution step 40: f(x)= 1418.37
# differential_evolution step 41: f(x)= 1418.37
# differential_evolution step 42: f(x)= 1418.37
# differential_evolution step 43: f(x)= 1418.37
# differential_evolution step 44: f(x)= 1418.36
# fvGP found hyperparameters  [1.00000000e+03 3.32121127e+00 7.16744574e-01]  with likelihood  1418.3391327449986  via global optimization

# %% [markdown]
# ## Looking at the posterior mean at the test points (remember that we did not define a particularly good kernel)

# %%
task_idx = 1

# %%
x_linspace = np.linspace(3*np.pi, 4*np.pi,100)
y_linspace = np.linspace(0,4,100)
x_grid, y_grid = np.meshgrid(x_linspace, y_linspace)
post_mean= obj.posterior_mean(np.column_stack((x_pred, task_idx*np.ones(x_pred.shape))))
posterior_mean = obj.posterior_mean(np.column_stack((x_grid.flatten(), y_grid.flatten())))

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(projection='3d')


ax.scatter(post_mean['x'][:,0], np.ones(100)*0,y_data[:,0])
ax.scatter(post_mean['x'][:,0], np.ones(100)*1,y_data[:,1])
ax.scatter(post_mean['x'][:,0], np.ones(100)*2,y_data[:,2])
ax.scatter(post_mean['x'][:,0], np.ones(100)*3,y_data[:,3])
ax.scatter(post_mean['x'][:,0], np.ones(100)*4,y_data[:,4])
ax.plot_surface(x_grid, y_grid, posterior_mean['f(x)'].reshape(100,100), rstride=1, cstride=1,cmap='inferno')
